# %% [markdown]
# # Data visualization

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dehe1011/QuantumDNA/blob/main/docs/tutorials/1_Plotting_Routines.ipynb)
#
# In this notebook you can explore the potential of data visualizations within the package. Learn how to create insightful plots that enhance the analysis and presentation.

# %%
# %pip install qDNA
# from qDNA import ROOT_DIR

# This can be used alternatively if you cloned the GitHub repository
import os
ROOT_DIR = os.getcwd()[:os.getcwd().rfind('QuantumDNA')]+ 'QuantumDNA'
os.chdir(ROOT_DIR)

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'
plt.rcParams['axes.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
from qDNA.tools import *
from qDNA import *

# %% [markdown]
# ## plot_eigenspectrum

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plt.subplots()
plot_eigv(ax, me_solver.tb_ham)

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
num_rows, num_cols = 3,3
fig, axes = plt.subplots(num_rows, num_cols, figsize=(5*num_cols, 5*num_rows) )
for i, ax in enumerate(axes.flatten()[:num_rows*num_cols]):
    plot_eigs(ax, me_solver.tb_ham, i)

# %% [markdown]
# ## plot_fourier

# %%
# parameters
kwargs=dict(particles=['electron'])
upper_strand, tb_model_name= 'GCG', 'WM'
tb_site = '(0, 0)'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plt.subplots()
plot_fourier(ax, me_solver.tb_ham, me_solver.init_state, tb_site, 'Period')

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'
J_list, J_unit = np.linspace(0,100,100), 'meV'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plt.subplots(1,3, figsize=(15,5))
plot_average_pop(ax, me_solver.tb_ham, J_list, J_unit)

# %% [markdown]
# ## plot_pop

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'
tb_site = '(0, 0)'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plt.subplots()
plot_pop_fourier(ax, me_solver.tb_ham, me_solver.init_state, tb_site, me_solver.times, me_solver.t_unit)

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'
tb_site = '(0, 0)'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plt.subplots()
plot_pop(ax, tb_site, me_solver)

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plt.subplots()
plot_coh(ax, me_solver)

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plot_pops(me_solver)

# %%
# parameters
kwargs=dict()
upper_strand, tb_model_name= 'GCG', 'ELM'
tb_site = '(0, 0)'

# plotting
me_solver = get_me_solver(upper_strand, tb_model_name, **kwargs)
fig, ax = plt.subplots()
plot_test_fourier(ax, tb_site, me_solver)
